# %% [markdown]
# ## Assignment 05 -  Sentiment Analysis

# %%
#!pip install nltk
#!pip install gensim

# %% [markdown]
# ##  Importing the Library

# %%
import pandas as pd
import re
import nltk
import gensim
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# ## Load the Data

# %%
data=pd.read_csv("/content/tweets.csv")

# %%
data.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
data.isnull().sum()
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
data['label'].unique()
# Out:
# array([0, 1])

# %%
len(data)
# Out:
# 7920

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7920 entries, 0 to 7919
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      7920 non-null   int64
#  1   label   7920 non-null   int64
#  2   tweet   7920 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 185.8+ KB

# %% [markdown]
# ## Cleaning the data

# %%
data=data[['label','tweet']]

# %%
data
# Out:
#       label                                              tweet
# 0         0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1         0  Finally a transparant silicon case ^^ Thanks t...
# 2         0  We love this! Would you go? #talk #makememorie...
# 3         0  I'm wired I know I'm George I was made that wa...
# 4         1  What amazing service! Apple won't even talk to...
# ...     ...                                                ...
# 7915      0  Live out loud #lol #liveoutloud #selfie #smile...
# 7916      0  We would like to wish you an amazing day! Make...
# 7917      0  Helping my lovely 90 year old neighbor with he...
# 7918      0  Finally got my #smart #pocket #wifi stay conne...
# 7919      0  Apple Barcelona!!! #Apple #Store #BCN #Barcelo...
#
# [7920 rows x 2 columns]

# %%
def preprocess_text(text):
  sentences=re.split(r'[.!?]', text)
  lemmatizer=WordNetLemmatizer()
  processed_sentence=[]
  for sentence in sentences:
    tokens=word_tokenize(sentence)
    tokens=[word.lower() for word in tokens if word.isalpha()]
    tokens=[word for word in tokens if word not in stopwords.words('english')]
    tokens=[lemmatizer.lemmatize(word) for word in tokens]
    if tokens:
      processed_sentence.append(" ".join(tokens))
  return processed_sentence

# %%
data["Cleaned_text"]=data['tweet'].apply(lambda x: preprocess_text(x))

# %%
data.head()
# Out:
#    label                                              tweet  \
# 0      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1      0  Finally a transparant silicon case ^^ Thanks t...
# 2      0  We love this! Would you go? #talk #makememorie...
# 3      0  I'm wired I know I'm George I was made that wa...
# 4      1  What amazing service! Apple won't even talk to...
#
#                                         Cleaned_text
# 0  [fingerprint pregnancy test http, android apps...
# 1  [finally transparant silicon case thanks uncle...
# 2  [love, would go, talk makememories unplug rela...
# 3  [wired know george made way iphone cute davent...
# 4  [amazing service, apple wo even talk question ...

# %% [markdown]
# ## Splitting the data

# %%
x_train, x_test, y_train, y_test= train_test_split(
    data['Cleaned_text'], data['label'],
    test_size=0.2,
    random_state=13
)

# %%
x_train
# Out:
# 1330    [available tpu ca, check http, co, iphone case...
# 6222    [hateapple never work like suppose useless cus...
# 1365    [view, travel traveldiaries travelphotography ...
# 4924    [apple lost customer, month ipamini still nigh...
# 928     [invested player match tv amazon prime deal, d...
#                               ...
# 2790     [http, justinbieber apple ipad iphone may, http]
# 7696    [caught vortex software update o discrepancy, ...
# 74      [happy sunday, samsung phone smile inception w...
# 6320    [ask digital camera flash stop working need ca...
# 338     [get anyone help applestore, everyone busy, sa...
# Name: Cleaned_text, Length: 6336, dtype: object

# %%
x_train.shape
# Out:
# (6336,)

# %%
x_test.shape
# Out:
# (1584,)

# %%
y_train
# Out:
# 1330    0
# 6222    1
# 1365    0
# 4924    1
# 928     0
#        ..
# 2790    0
# 7696    1
# 74      0
# 6320    1
# 338     1
# Name: label, Length: 6336, dtype: int64

# %% [markdown]
# ## Vectorizer the Data

# %%
model=gensim.models.Word2Vec(x_train, min_count=1)

# %%
words= model.wv.index_to_key
words
# Out:
# ['twitter',
#  'http',
#  'instagram',
#  'apple',
#  'pic',
#  'news photography fashion health fail tech ipad iphone funny lol',
#  'iphone',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow',
#  'would like wish amazing day',
#  'sup surf fun capetown funny sexy samsung pic',
#  'follow capetownsup instagram http',
#  'co',
#  'love',
#  'rhyme iphone',
#  'keep ya thing',
#  'hey guy',
#  'iphone http',
#  'html андроид android game news io apple iphone',
#  'look http',
#  'android http',
#  'sale',
#  'android apps unitedstate cute color igers iphoneonly guitarplayer iphone',
#  'android apps beautiful cute color igers iphoneonly iphone',
#  'ebay',
#  'redbubble',
#  'prophet husband',
#  'new phone',
#  'youtube',
#  'samsung',
#  'apple iphone',
#  'html',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow ff',
#  'exquisite squishy random charm http',
#  'check http',
#  'iphone strap toy decor free shop style sale today giveawaypic',
#  'happy',
#  'fuck',
#  'com',
#  'money today life twitch birthday sale android window nokia samsung iphone phone smartphone motorola offer bestprice jun',
#  'new baby',
#  'amazon',
#  'sony',
#  'apple rolling verizon iphone valentine day http',
#  'io',
#  'reallyreal w photobooth iphone ipad dating http',
#  'yeah',
#  'yay',
#  'followsunday followback rt teamfollowback follow retweet iphone',
#  'download shoppinglist app iphone http',
#  'lol',
#  'click http',
#  'fuck apple',
#  'com http',
#  'wtf',
#  'click link http',
#  'hateapple',
#  'finally',
#  'iphone discount case',
#  'iphone apple',
#  'iphone case',
#  'wow',
#  'much zeta supply',
#  'ugh',
#  'college sorority pic',
#  'brevity boxed calendar',
#  'hate apple',
#  'purchase download book http',
#  'fail',
#  'make every minute count tl today iphone accessory news life may',
#  'cool girl',
#  'myharbours',
#  'ff friend gratitude entrepreneur ipad iphone blackberry',
#  'iphone protective skin choose apple iphone model buy unique piece art iphone skin also providing scratch resistance http',
#  'love iphone',
#  'followtrick retweet follow rt followback gain today iphone sougofollow',
#  'hate',
#  'suck',
#  'kindle book march',
#  'good morning',
#  'time',
#  'new toy',
#  'make every minute count tl today iphone accessory news life august',
#  'support http',
#  'seriously',
#  'android',
#  'day',
#  'new apps iphone people sailing italy http',
#  'miss',
#  'michelle came home http',
#  'tcot nascar theater movie single ipad iphone',
#  'instapic mimmo',
#  'great',
#  'blogspot',
#  'wifi haking password http',
#  'yey',
#  'make every minute count tl today iphone accessory news life november',
#  'samsung http',
#  'make every minute count tl today iphone accessory news life january',
#  'haha',
#  'make every minute count tl today iphone accessory news life july',
#  'apple itunes',
#  'php',
#  'beauty shopping aliusaexpress iphone io app cat unlocked gsm lte',
#  'photo',
#  'yes',
#  'iphone case music discount',
#  'pissed',
#  'use http',
#  'iphone ipad',
#  'phone',
#  'got',
#  'iphone case technology',
#  'motorola',
#  'birthday',
#  'beautiful',
#  'apple pic',
#  'mr',
#  'make every minute count tl today iphone accessory news life december',
#  'thank much',
#  'ff friend gratitude ipad iphone blackberry entrepreneur',
#  'oh',
#  'apply http',
#  'hate iphone',
#  'one',
#  'relationship dating datingadvice lslpic',
#  'gain follower rt must follow follow back follow everyone rts gain ff iphone sougofollow',
#  'thanks apple',
#  'happiness',
#  'code http',
#  'omg',
#  'make every minute count tl today iphone accessory news life october',
#  'sweet',
#  'start today http',
#  'via ebay',
#  'hateiphones',
#  'life',
#  'money today life amazon birthday sale android window nokia samsung iphone phone smartphone motorola offer bestprice jul',
#  'apple fail',
#  'reallyreal app approved iphone ipad dating college http',
#  'right',
#  'make every minute count tl today iphone accessory news life february',
#  'really',
#  'amazing',
#  'new laptop',
#  'discount code twitter',
#  'make every minute count tl today iphone accessory news life april',
#  'zazzle',
#  'cutter free http',
#  'fuckyou apple',
#  'really apple',
#  'sony http',
#  'rt planet doug compassion iphone case zazzle',
#  'shop',
#  'iphonesia iphone instagood instagram photooftheday tweegram http',
#  'update',
#  'shop http',
#  'make every minute count tl today iphone accessory news life september',
#  'photobooth iphone ipad dating http',
#  'board',
#  'liked klip goodnight klip sleep restful tuesday bedtime iphone vlog http',
#  'new reallyreal',
#  'received new iphone x',
#  'finally got new phone',
#  'itunes apple',
#  'tt',
#  'like share want fast charger iphone iphone sa',
#  'tag friend design contemporary architecten architect arquitectura iphone mimar mimarlık araba car car instaarchitecture concept architektur architecture luxury http',
#  'ca wait',
#  'apple ipad',
#  'microsoft',
#  'wifinow',
#  'garden steemit http',
#  'twesbpic',
#  'weebly',
#  'ready',
#  'android apps unitedstate cute color iphoneonly guitarplayer iphone',
#  'money today life amazon birthday sale android window nokia samsung iphone phone smartphone motorola offer bestprice aug',
#  'itunes',
#  'love ninjanaptap iphone',
#  'angry',
#  'art crazy artwork design iphone case tshirtspic',
#  'com buy http',
#  'fb',
#  'littlewingman',
#  'casepeace',
#  'true',
#  'love apple',
#  'new headphone',
#  'iphoneography iphoneonly streetphotography iphonephotography mobilephotography mobile iphone apple color bright http',
#  'arrived',
#  'friday',
#  'love poem app http',
#  'product',
#  'lmao',
#  'apple mac',
#  'shoutouts indian malayali fun tbt tb tagging photography http',
#  'hahah',
#  'fucking hate apple',
#  'thanks',
#  'wait',
#  'hatemac',
#  'working',
#  'free',
#  'cool',
#  'check',
#  'ninja',
#  'ca agree',
#  'waiting',
#  'present',
#  'cnet',
#  'make every minute count tl today iphone accessory news life june',
#  'moby',
#  'buy cool gift today',
#  'college sorority single pic',
#  'welcome world baby',
#  'couple picture took',
#  'new art print http',
#  'photography samsung galaxy k zoom pic',
#  'photo quote day quote wisdom word smile follow tweetgram cute iphone fashion',
#  'apple http',
#  'mac',
#  'yo',
#  'college sorority single',
#  'yeay',
#  'view',
#  'dont miss http',
#  'good',
#  'hard plastic shaw',
#  'love iphone love romance girl iphone apple http',
#  'coming soon',
#  'actual fuck',
#  'last day vote dabball round',
#  'top photo app available http',
#  'ya',
#  'com giving u follow retweeting u followus mobile apps ff technology iphone appstore follow followme charity smallbiz rt apple digital business newappstore android instagram facebook follo digitalmarketingpic',
#  'chaildren kid sony أطفال سعادة http',
#  'ebony coffee table final coat',
#  'photographer outdoors getoutandexplore explore landscape slowingitdown photography beautiful apple mac macbookpro hashtag nofilter nikkor follow followme photo arty nikon photo takemorephotos',
#  'iphone app health fitness htc one x samsung galaxy tab iphone case',
#  'art game app iphone ipad itunes apple karma bribe browniepoints',
#  'gramophone',
#  'party hboshcupcakes',
#  'week',
#  'manythings',
#  'decision',
#  'abfadofficial thanks coming u',
#  'com giving u follow retweeting u followus mobile apps ff technology iphone socialmedia appstore follow followme gift charity smallbiz rt apple digital business newappstore android instagram facebook youtubepic',
#  'canoe ride',
#  'got new phone',
#  'retweet follow dealsplus win',
#  'need u',
#  'money today life amazon birthday sale android window nokia samsung iphone phone smartphone motorola offer bestprice',
#  'god',
#  'photo quote heart world thinkpink boy girl world pictoftheday photogram iphone',
#  'strong color steemit http',
#  'would',
#  'party',
#  'get erotic drink recipe weekend fun http',
#  'srsly',
#  'ff foodporn dj tokyo apple apps cbc gaming newyork sundaypic',
#  'kindle book april',
#  'major',
#  'customer cute light light wow apple yousaidthat',
#  'shoppinglist truelovecalculator relationship rateyourdate iphone lslpic',
#  'finally arrived',
#  'florida money today life twitch retweet twitter birthday sale android window nokia samsung iphone phone smartphone motorola lg sony offer bestprice instagram',
#  'planet doug compassion iphone case zazzle',
#  'f',
#  'college single pic',
#  'via havenlust',
#  'asshole apple',
#  'appstore io apple ipad itouch http',
#  'good day',
#  'apple fresh summer healthy diet food tastypic',
#  'holly shit',
#  'tip',
#  'droid',
#  'gain follower rt must follow follow back follow everyone rts gain iphone sougofollow g',
#  'samsung galaxy',
#  'android iphone apps make life fun filled music bestapps music http',
#  'happy friday',
#  'bomb',
#  'never',
#  'loving picoftheday selca selfie iphone http',
#  'smh',
#  'idiot',
#  'flag photo frame http',
#  'hacker wifi password prank http',
#  'like share want led selfie case samsung iphone',
#  'effing administrator',
#  'wish',
#  'snapdeal used order soemthin every alternate day',
#  'kindle book february',
#  'grrr',
#  'apple android',
#  'loser',
#  'siri iphone http',
#  'like share want totem phone case iphone iphone',
#  'playstation sony',
#  'shit',
#  'apple update',
#  'ask question http',
#  'like share want car accessory bag iphone samsung',
#  'askmeanything drandrew answer live',
#  'happygrumpy',
#  'twitter io suck',
#  'apple laptop',
#  'today http',
#  'retweet follow rt followback gain rt iphone sougofollow ff',
#  'price',
#  'businessinsider',
#  'hacking wifi http',
#  'make',
#  'si new phone si samsung champ http',
#  'unlockthesecrettoyoursoulmate',
#  'kawaii apple case pink polka dot smile fun',
#  'empowered',
#  'kindle book january',
#  'apple better replace piece phone cuz want alllllll money back',
#  'made',
#  'please support http',
#  'com giving u follow retweet followus mobile apps ff technology iphone appstore follow followme charity smallbiz rt apple digital business newappstore android instagram facebook follo marketing pic',
#  'bathroom selfie',
#  'happy mother day',
#  'rt usa follow',
#  'book doubt iphone http',
#  'best offer',
#  'universal smartphone car air vent mount holder cradle compatible iphonex',
#  'new year',
#  'eye',
#  'find',
#  'hacking password wifi prank http',
#  'mmm',
#  'mac o x',
#  'last',
#  'cute brain gon na explode',
#  'get order hard plastic shaw',
#  'joyful moment spent daughter proud dad haveaniceday shotoniphone iphonex http',
#  'microscopic stone chip stop everything',
#  'humming walkin',
#  'lie truth iphone deception heartbreak',
#  'hateorange',
#  'architecture iphonesia iphone instagood photooftheday tweegram villamorra shopping http',
#  'wind tree haveaniceday french mothersday timelapse shotoniphone iphonex http',
#  'quote day quote wisdom word smile follow tweetgram cute iphone fashion makeup',
#  'beauty shopping aliusaexpress iphone io app new edition lenovo ideacentre high performance fl',
#  'welcome home',
#  'today',
#  'facebook',
#  'high tech lightning usb cable foot',
#  'geek tech bot deal amazon home iphone ipad android samsung galaxy google gadget gift io technews power pc dev http',
#  'dictionaryvoice',
#  'priceless',
#  'satisfied customer',
#  'boy',
#  'beauty shopping aliusaexpress iphone io app xiaomi redmi dual sim lte factory unlocked',
#  'enjoy new ipad case',
#  'miggiq thank',
#  'suck apple',
#  'photo quote instagood insta sexy weed iphone cute kick summer lol fresh picoftheday',
#  'rt sharonhayes healthy dating',
#  'app http',
#  'need',
#  'apple headphone',
#  'delicious',
#  'real',
#  'iphone app',
#  'see u sent defective sony tv bro',
#  'funny',
#  'bekifft agree apple need detach synonymous fail blow',
#  'new one',
#  'twirus',
#  'annoying',
#  'awesome give try n ya free',
#  'swear',
#  'stackmark',
#  'new year cheerful fun smile sweet couple sony maya black party new day',
#  'love u',
#  'hacker wifi password http',
#  'coder life girl development computerscience iphone programming web programmer codinglife developer java dotnet javascript hacker game coffee apple education business work chocolate sweet foodphotography instagood',
#  'rt followbacg justinbieber apple ipad iphone april',
#  'com giving u follow retweeting u followus mobile apps ff technology iphone appstore follow followme gift charity smallbiz rt apple digital business newappstore android instagram facebook follo mediapic',
#  'samsung live laugh life instago instahub instamood http',
#  'audio proverb app listen repeat record listen learn',
#  'oldpic hdr xperiapicsitalia takenwithxperia sony sonyxperia fashion photooftheday photography art beautiful travel nature picoftheday ricadi capovaticano spiaggiadeltonopic',
#  'welcome',
#  'macbook apple',
#  'nice',
#  'hey',
#  'message',
#  'learn math sum ibbleobble',
#  'educational math game kid child kindergarten school school preschool homeschool homeschooling ipad iphone appletv indiedev playschool learning learnmaths number fridayfeelingpic',
#  'pic gone',
#  'trump attack mexican u',
#  'welcome family',
#  'hey apple',
#  'happy father day',
#  'help',
#  'fresh leaf steemit http',
#  'thanks shopify news sport health trump usa russi food iphone android',
#  'sir service please visit profile',
#  'people agree',
#  'hate iphone iphonesia instagram saturday http',
#  'woohoo',
#  'apps enhance facebook fan page http',
#  'iphonex pic',
#  'food apple pic',
#  'see many feature know iphone',
#  'iphone yourtechcompany pic',
#  'like saying easter v sound music r completely separate os',
#  'latest apple baby',
#  'pissedoff',
#  'newphone applefan newyear http',
#  'new',
#  'kindle book november',
#  'application nice iphone http',
#  'thank',
#  'iphone apple io deal gadget gift men woman tech news music video photo http',
#  'case missed',
#  'ff friend gratitude ipad iphone blackberry entrpreneur',
#  'apple iphone leather case smart apple iphone style swag cool http',
#  'applesucks',
#  'friend retrieve message http',
#  'use coupon code http',
#  'seriously apple',
#  'iphone iphone',
#  'ifttt instagrampic',
#  'weekday selfie friend foe friday iphone spawn r art purpose nature humanity piano music passionpic',
#  'hate apple product',
#  'portrait',
#  'ipad onlyknowwindows',
#  'att iphone',
#  'window',
#  'quote quote instagram instadaily photooftheday iphone iphonesia http',
#  'fail fail fail apple iphone',
#  'justinbieber apple ipad iphone may',
#  'com pic',
#  'new iphone',
#  'photo oh yeah',
#  'merry christmas',
#  'thankyou',
#  'bought',
#  'stupidiphone',
#  'house http',
#  'l',
#  'cute babylove sister bonding samsung http',
#  'love mahashivaratri',
#  'blackfriday cybermonday amazon deal iosdev gift movie gaming discount music song apps io iphone ipad http',
#  'get apple itunes gift card usd',
#  'apple done',
#  'ripoff',
#  'collection product check http',
#  'love city',
#  'c',
#  'apple suck',
#  'cute',
#  'kuwait pic iphone vote cairo googel youtube sidibouzid tunisia vote pic dont forget',
#  'apple samsung android',
#  'best',
#  'trying total monopolize smartphone industry',
#  'anonymous acting apple',
#  'christianpickuplines iphone ipad io nature http',
#  'h',
#  'lost everything',
#  'sale iphone case torras series liquid silicone ru',
#  'world photography day canon nikon sigma leica pentax sony whatever gear may u rise succeedpic',
#  'via youtube',
#  'awesome',
#  'ha',
#  'morning',
#  'want',
#  'appleevent apple',
#  'com fun',
#  'pick line app iphone',
#  'grr',
#  'ipad apple',
#  'happy announce entire store',
#  'new reallyreal w photobooth iphone ipad dating http',
#  'fear end http',
#  'fantastic',
#  'ask q http',
#  'drandrew still live',
#  'leftocentre gaycarboys slsandpet capitalteacher hey',
#  'sigh',
#  'iphone ipad io mondaymotivation',
#  'mondaymotivation http',
#  'purpose life live life purpose',
#  'pointless',
#  'download',
#  'get',
#  'new year goal sony lip rearlip trunklip mod honda newyear http',
#  'sony xperia unboxing newphone freeupgrade sony sexybeast excited gadget newtoy http',
#  'beauty shopping aliusaexpress iphone io app case beauty luxury leather wallet fli',
#  'look apple iphone x silver unlocked smartphone http',
#  'money today life twitch retweet twitter birthday sale android window nokia samsung iphone phone smartphone motorola offer bestprice jun',
#  'sony killed gtav public apology wont bring back excidement unraveling plot',
#  'thank http',
#  'soft grip battery case iphone powerplus ii perfect case fit snugly distributor andinobrand http',
#  'winter bow bling boot cute coach dress fashion followus girl hair iphone jean jacket',
#  'via redbubble redbubble sale discount iphonecases iphone christmas tshirt',
#  'teamdroid',
#  'francocovidirector ciak video chicco sonyvideo baby sony http',
#  'yahoo',
#  'samsung edge',
#  'see',
#  'like share want diamond case iphone iphone',
#  'iphonex',
#  'reason give whirl http',
#  'tried instagram yet',
#  'work hard work hard sun durisim sol crazy nolosaben felicitat felicidad samsung',
#  'said',
#  'apple everydayhttps',
#  'ig iphone nature igers photooftheday instadaily http',
#  'early birthday gift',
#  'tip http',
#  'retard decided use incredibly annoying whistling sound standard notification sound',
#  'fucking mac calendar fucking center',
#  'wired',
#  'last person discover charlieputh new al voicenotes streaming everywhere',
#  'thx',
#  'drshwetapuri working iphone running',
#  'ny nyc newyork newyorkcity manhattan westside nycphotographer nycphotography igers instagood instalike beautiful instagramhub explore exploretocreate iphonesia iphoneonly http',
#  'stupid',
#  'kapil sharma show latest episode saturday sony birthday',
#  'datingadvice drandrew live chat dating relationship lsl ask q http',
#  'flopshow enough',
#  'apple everyday',
#  'macciti',
#  'today pst',
#  'follower thanks inkstagram iphone instagram addiction wordphoto http',
#  'listen http',
#  'iphoneonly iphone musthave instacool shop shopping onlineshopping instashop instagood instafollow photooftheday picoftheday otstores sma',
#  'finally got upgrade',
#  'rt',
#  'change',
#  'still',
#  'small garden steemit http',
#  'moal boal',
#  'girlfriend valentinesday shot havilegrand mikeelbeta elijas sony mygirlfriend valentinespic',
#  'one night',
#  'simple card reader http',
#  'come macbook',
#  'apple fuckyou',
#  'let introduce girlfriend therealelijas mikeelbeta happy valentine day everyone',
#  'wan na know',
#  'hateapple gayyyyy',
#  'supposed great',
#  'new isweariwontdropit phone samsung mine phone portal companioncube http',
#  'ok apple',
#  'william gay horny girl vaio sony laptop snapback http',
#  'crappy company ipod wo open backup',
#  'best iphone game play cut rope tiny tank fruit ninja',
#  'iphone charger already breaking',
#  'saw cute guy got happy',
#  'year old',
#  'ipad apple clown ugly syked life hamui house http',
#  'samsungblast samsungdoomed',
#  'wait till tomorrow love',
#  'fun instagram instafun funny android samsung androidnesia http',
#  'samsung sell phone spec world moron',
#  'kernel panic',
#  'tech o',
#  'iloveit tv samsungtv samsung iwhan soon mi casa http',
#  'thanks new toy love u',
#  'soon mine',
#  'jump montreal life',
#  'second time scared crap iphone mothernaturegetoffyourperiod',
#  'newyear samsung newtoy http',
#  'big apple',
#  'frog one big jump steemit http',
#  'canada quebec summer trip girl view city travel observatoirepvm todayatapple iphonex observatoire place ville marie http',
#  'dessert delicious apple bigapple doughnut strawberry oreo joy dinner lu http',
#  'im back haha',
#  'thing love nike nikefc harleydavidson iphone iphonesia http',
#  'emergency alert really getting old',
#  'would make iphones',
#  'tot organic stage super morning apple cinnam',
#  'phone empty though icould didnt back x',
#  'rt god em boi sub b boosted civic honda sony http',
#  'phone died freakin kidding apple seven percent hateiphones hatemac tim cook literally worst',
#  'take ever contributes hatemicrosoft',
#  'frog jump new nature life blog story photo photo photography image image sony sonylens sonyphoto sonyphotography photofeed googel facebook facebook facebooknews news top follow look',
#  'android user feel apple ruling world apple appletech http',
#  'getting tired apple shit',
#  'iphones suck shitty',
#  'seenoncelebs iphone chill pic',
#  'bloated itunes always need',
#  'weekend summer pool full advantage sun gun flockoverdose water peace chilling spotify apple music heat wave life http',
#  'ladygaga loveforgagakiss appstore fan',
#  'protect iphone style search love potion chill pill phone case http',
#  'soon baby',
#  'mushkat figured part',
#  'useless frustrating confusing arrogent day delaying day ruining program ever',
#  'apple itunes pc ipad',
#  'tech',
#  'switching dark side jealous iphone haha',
#  'pose sunny londonlife sunglass chilled relax lunch samsung blessed damm stunned chicken factory http',
#  'mate stressed',
#  'error hate',
#  'went get samsung day advised',
#  'sometimes',
#  'work got club playlist dog pissedoff hatelaptops',
#  'connected internet cable',
#  'using loving',
#  'instagram upgrade introduces powerful new feature http',
#  'top germany',
#  'hohoho board like hangout bit instapost cover single youtuber bros http',
#  'bob marley redemption song fender music uprising bobmarley live life passion play guitar iphone',
#  'ruined phone even',
#  'mashable geekiest marriage proposal including iphone app',
#  'yay ipad white black apple new http',
#  'top world',
#  'bought huawei ascend sim data transferred co cant unlock iphone',
#  'guess time update iphone dammit http',
#  'theguardian',
#  'iosfails iossucks hateios',
#  'via youtube sony sony',
#  'resynced still luck',
#  'pharrell williams happy india day http',
#  'email loaded ipad since last night',
#  'new ipads',
#  'sony psn sony platin rang world germany virtuell digital kill game gamerpic',
#  'fucking annoyed apple news app available india',
#  'theoffice flaccid dick dry vagina news apple getting beat microsoft sony someone else',
#  'trapped',
#  'rt rt monteithelgort first post new phone samsung samsunggalaxy new',
#  'trapped art colorful portrait arunganesan iphone together graffiti http',
#  'updated mac password chrome wiped clean',
#  'pay factory fix',
#  'angry customerservice samsung',
#  'new vedio plz watch fight mad bangladesh http',
#  'detailed apple sslvulnerability',
#  'answer security question logging buy something',
#  'yeah apple',
#  'violatedpic',
#  'remove thing phone apple decided put',
#  'ipod come lamest headphone ever',
#  'still ca share news article',
#  'im happy bought christmas xmas bunny samsung calender sam pinkiepie pinkieeye',
#  'fun funny vine girl boy photooftheday instasize awesome water crazy mad followforfollow likeforlike passion smile travel adventure jump fail fall fit fitness iphonex fake',
#  'probs keeping iphone switch plan',
#  'post goody tomorrow course affordable price platform',
#  'would spend',
#  'kinda want window smartphone',
#  'last day earth',
#  'photographer outdoors getoutandexplore explore landscape photography beautiful apple mac macbookpro hashtag nofilter nikkor followme photo arty nikon photo takemorephotos',
#  'would night drop phone face bed every night',
#  'mind everything',
#  'get camera freeeeeeeeeeeeee xd',
#  'cheated outa',
#  'unacceptable behavior izone apple representative',
#  'iphone customerhttps',
#  'gilmore girl revival yup http',
#  'lovingshopping sony http',
#  'platin earned',
#  'think become',
#  'hardware company looking apple otherwise make internals inaccessible upgrade',
#  'buddha sony travel bangkok shaileshphotographypic',
#  'bought sony tablet',
#  'rt wating march madness phone iphone iphone http',
#  'awkward moment town called something total differnt new map iphone',
#  'followmeto apple orchard',
#  'apple applepicking fall fun healthy http',
#  'mac macbook pro macbookpro macintosh retinadisplay apple teamapple win http',
#  'procedure wait helped',
#  'chia cinnamon oat ounce pack yogurt',
#  'apple pieceofshit',
#  'love toby cat cute sweet awww amazing cat hashtag iphone even http',
#  'apple much right',
#  'rebooted iphoto deleted picture',
#  'freak',
#  'oh humanity',
#  'dantreacy galaxy removed stuck ipad instead',
#  'phone charger finally decides take',
#  'cat catsofinstagram instacat catlover purring purringcat cat whisker pussyinmyface arcadia phoenix arizona iphonex nofilter http',
#  'sad thing tht none icloud backup worked',
#  'dang would',
#  'signed former customer',
#  'mcuban dear apple really accomplish patent lawsuit',
#  'photo campanile sorus liguria italy iphone iphoneday iphonelove iphonebestphoto likeforlike',
#  'played minute family guy lost battery',
#  'pee wee grill',
#  'anyone got one adaptor thing put iphone sim put real phone',
#  'phone europe lte japan wifi device travel http',
#  'lenovo motorola doublecam funny http',
#  'got much http',
#  'ordered amazing photo new iphone case',
#  'via techcrunch apple apple',
#  'launch looming apple seek injunction stop galaxy iii sale http',
#  'electronics nammaviveks expert chennai backtocollege sale offer discount emi student college happiness apple iphone iphonex coolpic',
#  'celebrate happiness u http',
#  'happy like camera friday babe',
#  'laptop work nikamirnezam dinasour laptop macbookpro apple',
#  'new hoesje samsung galaxy lll vistaprint affie white lv http',
#  'etc',
#  'installing free program create appleid verify id initiate id giving cc information',
#  'child day http',
#  'rt kid samsung born',
#  'got game today sony limitededition http',
#  'charged ipad ready comic con',
#  'samsung galaxy good',
#  'thirsty got ta see',
#  'purchase day',
#  'almost lost iphone today r reunited iphone',
#  'excited unbox new baby tv samsung new http',
#  'new tele',
#  'jobpounce iphone sinanews lastfm music hiring',
#  'job search remixed june http',
#  'goodday gaming geek destiny sony micromania http',
#  'battery issue iphone made appointment walked away brand new iphone',
#  'ipads expensive apple ipad suck ipads rich tablet affordable paper board game poor',
#  'great customer service apple',
#  'ill try find volume turn ive never used iphone http',
#  'dontstop well think im done falling love w song home bed laptop sony headphone',
#  'pixel dash sticker imessage app http',
#  'pixeldash free apple appstore',
#  'videogamesday',
#  'best happy ending scene sad ending ending apple eye xianjing http',
#  'dat cool itunes crash wipe ipod',
#  'hohoho',
#  'cause happy',
#  'give u call',
#  'ipad mini wifi stock',
#  'samsung galaxy new android http',
#  'got new baby',
#  'bout go shopping listening music iphone justme music likeforlike http',
#  'tv smart tv samsung mundial soccermode http',
#  'little bro ignation ig igaddict instago iphonesia instagood instagramhub instamood iphone http',
#  'follow instagram iphoneography iphonesia instagood photooftheday iphone ig ige http',
#  'proper car porn weekend',
#  'reposting presdak iphonecase samsungcase followme iphone samsung phonecase follow',
#  'behalf samsung bunch u distributed notebook govt school kid around bangalore',
#  'listen heart iphone idea iraq jordan amman amazing fun http',
#  'apple stevejobs apple ipad mac like http',
#  'happiness simple need think',
#  'fatmanbcfc imessage working keep asking sign apple id say password wrong',
#  'iphonesia iphone instagood instagram photooftheday tweegram ipho http',
#  'happyowlstudio ipad cashbox',
#  'bye bye sony keep walking',
#  'gon na instagood instadaily twelveskip iphone like http',
#  'use android',
#  'mr phone',
#  'long take',
#  'jarstalking back everything',
#  'lastday sony work redbull sony http',
#  'say prayer instagram iphone photography birthday pray cake http',
#  'phone samsung samsunggalaxynote nyappy http',
#  'seriously switch teamandroid first peteykandola phone mess update laptop apple macbookpro',
#  'josh duggar offer http',
#  'green small sun try nature photo photo photography image image sony sonylens sonyphoto sonyphotos sonyphotography follow photofeed gallery home naturephotography top',
#  'fresh green steemit http',
#  'learn junior graphic designer course channel apple iphone ipad applewatch dubai tech madewithover apps bestofover design graphic graphicdesignerspic',
#  'lesson download font free io design photo http',
#  'rt rt new phone house',
#  'goo',
#  'gaza seaport last resort',
#  'see google launching jelly bean still waiting ic samsung tablet',
#  'someone tell apple new iwork version big time',
#  'photo justinproo projectartsociety party apple art artsociety drug life vintage',
#  'um yeah u got ta love friend leanamarie locked iphone spam http',
#  'photo vietnam food yummy delicious hungry random like fun fat instagram iphone veggie',
#  'android samsung facebook twitter ig instalike instacanada http',
#  'multitasking phone',
#  'loving new ipad case ipad apple smartcover red http',
#  'happy birthday pop birthday rabbit banana apple pop http',
#  'work nothing happened fail mac apple saved',
#  'hard disk crashed godthanks bought superduper',
#  'alaska kindness anchorage adventure fall iphone jw http',
#  'wild wind blow',
#  'hahaha watchface samsung tizen smartwatch watchface ha animation freepic',
#  'work blessed new iphone iphone new work phone http',
#  'palestine gaza sea seaport mediterranean sky blue mosque view life live resort beautiful beauty mobile sony camera saturday november smile city morning day sunny sunshinepic',
#  'leave alone parrot parakeet adorable bird funny malaysia sony zoo johor http',
#  'unbelievably terrible',
#  'apple gadget electronics cellphone toronto eatoncenter http',
#  'iphonehater',
#  'plussssss scam adapter use accessory errrrrr',
#  'upgrade iphone',
#  'think today day',
#  'tried calling store automatedsystem would let',
#  'frustrated apple customer service',
#  'lil boyfriend baby boy family cute beautiful kid kidstagram daily photitos iphone iphonesia http',
#  'nexus sold like hot cake side pond',
#  'apple piecesofshit',
#  'break phone make pay dollar another one work correctly',
#  'new phone case iphone case mint green bow pearl pretty http',
#  'cellmefree',
#  'thank super weekend phone apple addict http',
#  'less hour already frozen apple',
#  'news uk android version mag yet',
#  'birthday apple write nickname began acquaintance http',
#  'found tweetdeckapp iphone realizing effing fantastic',
#  'mint peach obsession mine girl woman bracelet mint peach spring iphone iphonesia ipho http',
#  'girl brazil life photo face happiness samsung friday ana http',
#  'picture phone dunno thought looked cool picture memory iphone http',
#  'fml firstworldproblems apple epicfail',
#  'migration assistant seamless',
#  'kelly',
#  'gocougs utpol r b jagged edge dru hill sade r',
#  'let one know simple push button new allstate app iphone http',
#  'quality team samsung galaxy note nofilter selfie paper art mcdonald http',
#  'cheesing selfportrait portrait smile laugh ignation igers iphoneography iphonesia iphone igers http',
#  'yellow nature color color new story blog photo photo photography image image sony sonylens sonyphoto sonyphotos sonyphotography photofeed news top wow cool like look color colorphotography',
#  'first yellow steemit http',
#  'sony favoritegame',
#  'best game time',
#  'sonic adventure psn insta buy',
#  'iphone twelveskip iphonesia apple tech photooftheday instadaily http',
#  'tea time',
#  'instead syncronising new music delete apps',
#  'photo mykita sunny sunglass gold golden reflecting life shade selfie iphone',
#  'know dirty secret sony',
#  'apple bid outflank android tech giant unveils new plastic iphone mailonline moneygrabbers',
#  'good night life iphoneonly live instagram iphone fierce queen gay brazil make club nigh http',
#  'screen android wifi tablet samsung http',
#  'black friday blackfriday tagforlikes beautiful self girl picoftheday free shipping check new samsung galaxy tab',
#  'problem phone samsung mobile instapic http',
#  'throwbackthursday baby boy man family kid tbt igers iphone webstagram http',
#  'new dress s shopping clothes fav denim orange pink selfie iphoneonly http',
#  'still programmed basic rt apple suck',
#  'valentinesday iphone pic',
#  'check loveable wallpaper http',
#  'need valentine day iphone wallpaper',
#  'feel betrayed',
#  'got emotionally invested tv ad last second apple logo appear',
#  'live demo pc',
#  'spreadinghappiness nephew apple',
#  'sony christmas gift precious console gamer http',
#  'gaming',
#  'come apple unimpressed',
#  'mi connecting itunes geniusbar appointment available',
#  'galaxy speedy king smartphones confirmed samsung apple io android iphone iphonex review camera speed speedtest best king mobile smartphone tech trend nextbigthing better great http',
#  'itunes try load music every usb drive plug refuse sync actual ipod',
#  'gaming worldofwarcraft wod cat computer allianz gnom priest samsung pic',
#  'yes world warcraft',
#  'stillwontbuyandroidtho',
#  'connected',
#  'sway',
#  'phone literally plugged sudden shot',
#  'elpoliedro saturday morning nofilter dreamjob sun apple sony poliedro http',
#  'filming new cinema movie cinema camera film project xdcam sony canon fun http',
#  'sony really pissing wo let sign playstation',
#  'happy new year bitchesssss newyear like cute boy samsung galaxy gay http',
#  'fuck fix iphone plus phantom touching bend screen stop responding apple',
#  'holding baby first time',
#  'fucking hate itunes',
#  'look nut ollo',
#  'home steemit http',
#  'massive sale iphone tempered gl plus follow u http',
#  'notreally sony',
#  'thank sony wonderful product',
#  'fucked',
#  'olloclip washington money art government usa secret http',
#  'thank everyone subscriber youtube subscribe subscriber twitch gaming fun xbox sony game xbox sony pic',
#  'never loathed company much loathe apple moneysuckingbastards done product forever',
#  'fastcompany ipad iphone applewatch',
#  'many time apple exec used today event',
#  'working much mac work messing window keyboard shortcut happy',
#  'happyowlstudio',
#  'retail cash money apple ipad sale http',
#  'unique cool modern beautiful',
#  'home story blog life art artphotography artphoto photo photo photography image image gallery sony sonylens lens sonyphoto sonyphotos sonyphotography sonystory follow wow photofeed feed top color blue sky',
#  'problem samsung galaxy froyo',
#  'new phone case screen protector like iphone freedom droid ftw',
#  'hug follow like iphone tattoo christmas beautiful newyork http',
#  'rockingtherazernowpic',
#  'finally fixed apple issue genius could help',
#  'jadorefancy followsunday followback rt teamfollowback follow retweet iphone',
#  'cwbydrnkscrft http',
#  'first queue',
#  'got bandana behaves nail cut c apple chihuahua cute mybaby http',
#  'l ny',
#  'well lagfix',
#  'look landed basket samsung newphone tall tallgirls tallandproud vitiligo vitiligobeauty prosphetics youtube smallyoutuberarmypic',
#  'puppyrush puppyrush puppy dog pug labrador woof poodle husky puppylove westie cutepuppies apple google appstore pic',
#  'puppy rush game involving cute puppy real life cute pupsfollow puppydailyposts',
#  'deep magenta http',
#  'sun tonight insane',
#  'okay apple camera suck',
#  'multitasking brain medium infographic http',
#  'gratitude bless entrepreneur iphone ipad blackberry',
#  'leigh bought samsung tablet yesterday',
#  'fun time summer sun cloud water beautiful flower friend fun http',
#  'animal ave bird guacamaya friend beauty blue yellow http',
#  'new friend',
#  'sale discount saving fun primeday iphone memorialdaysalepic',
#  'click',
#  'capsule collection case memorial day',
#  'take photograph make',
#  'wow neversettle oneplus pic',
#  'well done sony free game month towerfallascention strider great game http',
#  'oneplus getpeid brand new oneplus',
#  'love u couple friend girl boy sunglass fun samsung igersmaracay igersvenezuela p http',
#  'good night good night sony camera sweet girl cool today http',
#  'skype microsoft apple iphone ipad window gadget hate fail trending let get go',
#  'let get ihatemicrosoft trending',
#  'full screen video work galaxytabpro update samsung',
#  'welcome family future samsung consultancy ilovemyjob http',
#  'might visit one awful geek infested apple shop work',
#  'samsung tablet galaxynote boyfriend http',
#  'iphoneisa iphone mini swag ootd photooftheday lol http',
#  'fuck awesome apple',
#  'minion dave iphone cover minion minion miniondave despicableme instagood iphone oohello',
#  'best line look phone take business day',
#  'never bought samsung',
#  'new baby merry christmas samsung christmas http',
#  'bow bridge central park nyc',
#  'one million tobie home bedroom mirror samsung galaxie inlove http',
#  'also wolfgangwolfe go fuck say one goddamned fucking word',
#  'listening get girl',
#  'iphone music',
#  'listening playing hungry shark evolution',
#  'lcd black old model http',
#  'instalike sony mp waterproof digital camera',
#  'sony fuck',
#  'samsungmobileus samsung thank update',
#  'kid zip hoodie much zeta supply',
#  'clean speed http',
#  'socialmedia socialmediaapp picoftheday instadaily style friend connection iphone android io startup app androidapp samsunggalaxy googlepixel htc sony google onepluspic',
#  'youtube browser fucking shit start redirecting normal youtube link',
#  'protip sony',
#  'iphone igersbsb iphoneonly igersbrasil amor ring vine hand swarovski antiquarius grill http',
#  'redeem apphookup io iphone game playing free today art indiegame art puzzle fun http',
#  'hi bathroom selfie iphone apple sunday beautiful relax http',
#  'iphone iphonesia iphoneonly picoftheday pic android lipenemo jj cearaemfotos jardim frotin http',
#  'development underway android user',
#  'gon na walk apple device piece crap annoyed beyond sticking',
#  'another happy customer batman case samsung edge batman crystal pic',
#  'iphone hopeeverythingistherewhenifinishrestoring cool',
#  'phone locked say oasscode incorrect know',
#  'gear filmlife shortfilm brisbane bts photography ninja sony http',
#  'letsgo cardiokiller stressreliever faith hope god spotify iphone powerbeats',
#  'enjoy bike ride',
#  'forgot give shoutout empiretheatres whitby ease purchasing ticket samsung galaxy simple customer',
#  'prick sony',
#  'bye iphone hello iphone apple blue http',
#  'gutting moment hash button computer copy paste apple macbook',
#  'thank ht star point',
#  'samsung ceo passion star workhard fun recognition http',
#  'first underwater picture phone',
#  'feelingexcited sony http',
#  'minhas case capinhas iphone cute amo encantadoras ly cool baphonicas http',
#  'apple suck big time',
#  'incredible',
#  'buy expensive iphone',
#  'come new one update',
#  'suddenly start fail',
#  'apple gon na buy',
#  'hk case came today',
#  'hellokitty hk asian phone case iphone obsessed blue white bow http',
#  'lindahamui life',
#  'portuguese audio proverb app released',
#  'fml iphone',
#  'updating ipad io',
#  'message u try best order',
#  'struggling find accessory mobile',
#  'discipline world success travel trump quote motivation thursdaythoughts todaysor idol perfume makeup luxury news ariane car life relationship watch youtube iphone fashion hope',
#  'finally phone working reset whole thing download sadday',
#  'oh sure',
#  'iphone working fine got io update wo stop freezing shutting apps',
#  'apple iphoneproblems',
#  'enough room take photo enough room download apps',
#  'samsunggalaxyiiii samsung galaxy http',
#  'fuck iphone yo galaxy',
#  'people iphones keep showing',
#  'yet email',
#  'phone say email',
#  'upgrade hardwareupgradespic',
#  'hour left enjoy new samsung ssd macbook',
#  'southport liverpool apple samsung case cover design tuesday wednesday mobile smartphone phone datacable charger woman men fashion designerpic',
#  'iphone cause want another stupid useless app remove',
#  'true i̇stanbul',
#  'hello cutie welcome home samsung galaxy ispoiledmyself http',
#  'work interview',
#  'sad true',
#  'steve job wiki page say dead',
#  'stuck phone even know made week badtimes',
#  'weekend weekend picoftheday shoot shooting tfp tfpmodel tfpshooting model modeln camera kamera fun fotografie photography fotograf photograph hobby fotoshooting photoshooting sony sonyalpha kaiedel artofportrait http',
#  'hello new baby yey early christmas gift blessed samsung http',
#  'autumn sky instagood iphone iphoneonly autumn red fall leaf orange cold london beauti http',
#  'djmisterquindi unboxing thanks tronsmart sending elementpixie tronsmart luissuarez speaker speakerphone powersound music enjoy dj djmisterquindi wireless bluetooth portable luxury bose jbl sony bangolufsen ha',
#  'fuckpc even bigger fuckyou apple',
#  'laptop wont fucken work',
#  'got home getting iphone replaced took fucking ever even replace apple',
#  'samsung smarttv led hd',
#  'getting new tv today',
#  'weekend shopping best offer uae techlink samsung mobile iphone phone visit nearest',
#  'taking ipod',
#  'smartphones need case function',
#  'smartphones come free case',
#  'makeup show nyc nyc makeup instagram iphone iphoneograpgy iphonesia picoftheday http',
#  'updated apps',
#  'hopei nyc wandering camera iphone red http',
#  'find hope everywhere',
#  'urge game purchased lol epic gtv gaming sony http',
#  'iphone apple phone technology tech sad rejection sirisays puppy boo mehpic',
#  'even siri noncommittal',
#  'apps stuck killing everything back normal apple fail',
#  'itunes window screwed machine',
#  'via redbubble fungi pun funny cute adorable cartoon emoji painting illustration drawing redbubble shirt phonecase galaxy samsung android iphone laptopcase pillow bag totebag decor sticker notebook journal',
#  ...]

# %%
model.wv['apple']
# Out:
# array([-8.67612381e-03,  1.11035015e-02,  1.17128494e-03,  4.42312303e-04,
#         5.77644119e-03, -4.63615777e-03,  2.65751150e-03,  9.17621981e-03,
#         4.17224783e-03, -1.01391105e-02,  1.00548202e-02,  3.03418073e-03,
#         3.38136079e-03, -5.46626002e-03,  1.00850817e-02, -2.69720331e-03,
#         1.06156180e-02, -5.65441139e-03, -9.56771243e-03,  4.83175786e-03,
#         1.87904842e-03, -3.12777306e-03,  1.10531235e-02,  9.35880281e-03,
#        -8.65739770e-03,  2.75340956e-03,  6.89980853e-03,  3.38952756e-03,
#         5.89843257e-04, -8.02302238e-05,  2.29967805e-03, -5.35097392e-03,
#        -7.73315132e-03, -3.15018045e-03,  2.51408131e-03,  9.60680377e-03,
#         1.18148755e-02, -6.93685049e-03, -9.72571597e-03,  8.56227800e-03,
#         2.91755563e-03,  4.51191235e-03,  5.62527031e-03, -3.12775187e-03,
#         8.30421969e-03,  2.31963862e-03,  1.65905594e-03, -3.16052046e-03,
#        -2.88119004e-03, -9.26915323e-04,  6.11332059e-03, -1.22857175e-03,
#        -1.10851834e-02, -1.13241104e-02, -7.61818187e-03,  8.43926799e-04,
#         3.60955903e-03,  9.65455361e-03,  4.14195424e-03, -4.27784864e-03,
#         1.98934722e-04,  4.93934145e-03,  8.18755198e-03, -2.84858467e-03,
#         3.50636663e-03, -5.58826886e-03,  8.00092472e-04,  9.78295226e-03,
#        -2.91382079e-03, -8.25625844e-03,  6.81356248e-03, -3.03421821e-03,
#        -3.06298432e-04,  1.01889726e-02, -2.43501877e-03, -4.20336053e-03,
#        -4.74449387e-03,  9.40142665e-03, -7.00996770e-03,  1.51067949e-03,
#        -7.16846203e-03,  5.49692940e-03,  4.91790520e-03,  2.47446820e-03,
#        -2.09683646e-03, -3.66170472e-03,  1.04351491e-02,  4.12811432e-03,
#        -1.48521306e-03, -8.17326363e-03, -7.57163577e-03, -4.80358431e-04,
#        -6.62053571e-05, -3.48902284e-03,  1.27282459e-02,  7.55460933e-04,
#         7.12537020e-03, -9.37047694e-03, -3.54474178e-03, -4.71298024e-03],
#       dtype=float32)

# %%
x_train_vec = []
for ls in x_train:
  vectors=[]
  for word in ls:
    if word in words:
      vectors.append(model.wv[word])
  x_train_vec.append(np.array(vectors))

# %%
x_test_vec=[]
for ls in x_test:
  vector=[]
  for word in ls:
    if word in words:
      vector.append(model.wv[word])
  x_test_vec.append(np.array(vector))

# %%
x_train_vec_avg=[]
for v in x_train_vec:
  if v.size:
    x_train_vec_avg.append(v.mean(axis=0))
  else:
    x_train_vec_avg.append(np.zeros(100, dtype=float))

# %%
x_test_vec_avs=[]
for v in x_test_vec:
  if v.size:
    x_test_vec_avs.append(v.mean(axis=0))
  else:
    x_test_vec_avs.append(np.zeros(100,dtype=float))

# %% [markdown]
# ## Creating the model

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train_vec_avg, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=rf.predict(x_test_vec_avs)
accuracy_score(y_test, y_pred)
# Out:
# 0.759469696969697

# %% [markdown]
# ## Another way of doing

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report

# %%
clf=Pipeline([
    ("Vectorizer", TfidfVectorizer()),
    ("Random Forest", (RandomForestClassifier()))
])

# %%
print(type(x_train[0]))
print(x_train[0])
# Out:
# <class 'str'>
# available tpu ca check http co iphone case music discount

# %% [markdown]
# # changing the list into string for the TfidfVectorizer

# %%
x_train = [' '.join(tokens) if isinstance(tokens, list) else tokens for tokens in x_train]

# %%
x_test = [' '.join(tokens) if isinstance(tokens, list) else tokens for tokens in x_test]

# %%
clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('Vectorizer', TfidfVectorizer()),
#                 ('Random Forest', RandomForestClassifier())])

# %%
y_pred=clf.predict(x_test)

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8825757575757576

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92      1188
#            1       0.77      0.76      0.76       396
#
#     accuracy                           0.88      1584
#    macro avg       0.84      0.84      0.84      1584
# weighted avg       0.88      0.88      0.88      1584
