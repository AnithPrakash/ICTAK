# %% [markdown]
# ## Importing Library for model creation and  Data Preprocessing

# %%
import pandas as pd
import re
import string
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import WordNetLemmatizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# ## Preprocessing the Data

# %%
data=pd.read_csv("/content/tweet_emotions.csv")
data
# Out:
#          tweet_id   sentiment  \
# 0      1956967341       empty
# 1      1956967666     sadness
# 2      1956967696     sadness
# 3      1956967789  enthusiasm
# 4      1956968416     neutral
# ...           ...         ...
# 39995  1753918954     neutral
# 39996  1753919001        love
# 39997  1753919005        love
# 39998  1753919043   happiness
# 39999  1753919049        love
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 3 columns]

# %%
# finding the shape of the data
data.shape
# Out:
# (40000, 3)

# %%
# the info of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  object
#  2   content    40000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 937.6+ KB

# %%
# drop the tweet id col because its irrelevant for the model creation
data1=data.drop('tweet_id', axis=1)
data1.head()
# Out:
#     sentiment                                            content
# 0       empty  @tiffanylue i know  i was listenin to bad habi...
# 1     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2     sadness                Funeral ceremony...gloomy friday...
# 3  enthusiasm               wants to hang out with friends SOON!
# 4     neutral  @dannycastillo We want to trade with someone w...

# %%
#type of emotion present in the dataset
data1['sentiment'].unique()
# Out:
# array(['empty', 'sadness', 'enthusiasm', 'neutral', 'worry', 'surprise',
#        'love', 'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger'],
#       dtype=object)

# %%
labels=['empty', 'sadness', 'enthusiasm', 'neutral', 'worry', 'surprise',
       'love', 'fun', 'hate', 'happiness', 'boredom', 'relief', 'anger']

# %%
# The total number of emotion
data1['sentiment'].nunique()
# Out:
# 13

# %%
# groupby the count of the emotion in the dataset
emotion_count=data1.groupby(['sentiment'])['sentiment'].count()
emotion_count
# Out:
# sentiment
# anger          110
# boredom        179
# empty          827
# enthusiasm     759
# fun           1776
# happiness     5209
# hate          1323
# love          3842
# neutral       8638
# relief        1526
# sadness       5165
# surprise      2187
# worry         8459
# Name: sentiment, dtype: int64

# %%
# sorting the groupby methods
emotion_count.sort_values(ascending=False)
# Out:
# sentiment
# neutral       8638
# worry         8459
# happiness     5209
# sadness       5165
# love          3842
# surprise      2187
# fun           1776
# relief        1526
# hate          1323
# empty          827
# enthusiasm     759
# boredom        179
# anger          110
# Name: sentiment, dtype: int64

# %%
# Checking weather it contain null values
data1.isnull().sum()
# Out:
# sentiment    0
# content      0
# dtype: int64

# %% [markdown]
# #Cleaning the text

# %%
data1['content']
# Out:
# 0        @tiffanylue i know  i was listenin to bad habi...
# 1        Layin n bed with a headache  ughhhh...waitin o...
# 2                      Funeral ceremony...gloomy friday...
# 3                     wants to hang out with friends SOON!
# 4        @dannycastillo We want to trade with someone w...
#                                ...
# 39995                                     @JohnLloydTaylor
# 39996                       Happy Mothers Day  All my love
# 39997    Happy Mother's Day to all the mommies out ther...
# 39998    @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999    @mopedronin bullet train from tokyo    the gf ...
# Name: content, Length: 40000, dtype: object

# %%
# Remove the number and special char from the content and making it lowercase

# %%
data1
# Out:
#         sentiment                                            content  \
# 0           empty  @tiffanylue i know  i was listenin to bad habi...
# 1         sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2         sadness                Funeral ceremony...gloomy friday...
# 3      enthusiasm               wants to hang out with friends SOON!
# 4         neutral  @dannycastillo We want to trade with someone w...
# ...           ...                                                ...
# 39995     neutral                                   @JohnLloydTaylor
# 39996        love                     Happy Mothers Day  All my love
# 39997        love  Happy Mother's Day to all the mommies out ther...
# 39998   happiness  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999        love  @mopedronin bullet train from tokyo    the gf ...
#
#                                             Cleaned_text  emotion
# 0      [iffanylue, i, know, i, was, listenin, to, bad...        2
# 1      [layin, n, bed, with, a, headache, ughhhh, ......       10
# 2          [funeral, ceremony, ..., gloomy, friday, ...]       10
# 3         [wants, to, hang, out, with, friends, soon, !]        3
# 4      [annycastillo, we, want, to, trade, with, some...        8
# ...                                                  ...      ...
# 39995                                   [ohnlloydtaylor]        8
# 39996               [happy, mothers, day, all, my, love]        7
# 39997  [happy, mother, 's, day, to, all, the, mommies...        7
# 39998  [iariley, wassup, beautiful, !, !, !, follow, ...        5
# 39999  [opedronin, bullet, train, from, tokyo, the, g...        7
#
# [40000 rows x 4 columns]

# %%
def clean_text(text):
    text = re.sub('@[A-Za-z0-9_]+', '', text)  # Remove the mentions
    text = re.sub('https?://[A-Za-z0-9./]+', '', text)  # Remove URLs
    text = re.sub('[^a-zA-Z]', ' ', text)  # Remove non-alphabetic characters
    text = text.lower()  # Convert to lowercase
    text = word_tokenize(text)  # Tokenization
    text = [word for word in text if word not in set(stopwords.words('english'))]  # Remove stopwords
    #stemmer = PorterStemmer()
    lemmatizer= WordNetLemmatizer()
    #text = [stemmer.stem(word) for word in text]  # Stemming
    text=[lemmatizer.lemmatize(word) for word in text]
    return ' '.join(text)

# %%
data1['Cleaned_text']=data1['Cleaned_text'].apply(clean_text)

# %%
data1
# Out:
#         sentiment                                            content  \
# 0           empty  @tiffanylue i know  i was listenin to bad habi...
# 1         sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2         sadness                Funeral ceremony...gloomy friday...
# 3      enthusiasm               wants to hang out with friends SOON!
# 4         neutral  @dannycastillo We want to trade with someone w...
# ...           ...                                                ...
# 39995     neutral                                   @JohnLloydTaylor
# 39996        love                     Happy Mothers Day  All my love
# 39997        love  Happy Mother's Day to all the mommies out ther...
# 39998   happiness  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999        love  @mopedronin bullet train from tokyo    the gf ...
#
#                                             Cleaned_text  emotion
# 0      iffanylu know listenin bad habit earlier start...        2
# 1                 layin n bed headach ughhhh waitin call       10
# 2                           funer ceremoni gloomi friday       10
# 3                                  want hang friend soon        3
# 4      annycastillo want trade someon houston ticket one        8
# ...                                                  ...      ...
# 39995                                     ohnlloydtaylor        8
# 39996                              happi mother day love        7
# 39997  happi mother day mommi woman man long momma so...        7
# 39998  iariley wassup beauti follow peep new hit sing...        5
# 39999  opedronin bullet train tokyo gf visit japan si...        7
#
# [40000 rows x 4 columns]

# %% [markdown]
# ## Trying CountVectorize model

# %%
vectorizer=CountVectorizer()
x=vectorizer.fit_transform(data1['Cleaned_text'])

# %%
label_encode=LabelEncoder()
data1['emotion']=label_encode.fit_transform(data['sentiment'])

# %%
labels
# Out:
# ['empty',
#  'sadness',
#  'enthusiasm',
#  'neutral',
#  'worry',
#  'surprise',
#  'love',
#  'fun',
#  'hate',
#  'happiness',
#  'boredom',
#  'relief',
#  'anger']

# %%
data1
# Out:
#         sentiment                                            content  \
# 0           empty  @tiffanylue i know  i was listenin to bad habi...
# 1         sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2         sadness                Funeral ceremony...gloomy friday...
# 3      enthusiasm               wants to hang out with friends SOON!
# 4         neutral  @dannycastillo We want to trade with someone w...
# ...           ...                                                ...
# 39995     neutral                                   @JohnLloydTaylor
# 39996        love                     Happy Mothers Day  All my love
# 39997        love  Happy Mother's Day to all the mommies out ther...
# 39998   happiness  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999        love  @mopedronin bullet train from tokyo    the gf ...
#
#                                             Cleaned_text  emotion
# 0      iffanylu know listenin bad habit earlier start...        2
# 1                 layin n bed headach ughhhh waitin call       10
# 2                           funer ceremoni gloomi friday       10
# 3                                  want hang friend soon        3
# 4      annycastillo want trade someon houston ticket one        8
# ...                                                  ...      ...
# 39995                                     ohnlloydtaylor        8
# 39996                              happi mother day love        7
# 39997  happi mother day mommi woman man long momma so...        7
# 39998  iariley wassup beauti follow peep new hit sing...        5
# 39999  opedronin bullet train tokyo gf visit japan si...        7
#
# [40000 rows x 4 columns]

# %%
x_train, x_test, y_train, y_test=train_test_split(x , data1['emotion'], test_size=0.2, random_state=13)

# %%
model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
predictions = model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.314375

# %% [markdown]
# ## SVM Model

# %%
svm=SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
predictions_svm =svm.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, predictions_svm))
# Out:
# Accuracy: 0.356875

# %% [markdown]
# ## Trying spacy library
#
# - Because of the lower accuacry in nltk i tried spacy

# %%
import spacy

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def preprocess(text):
  doc=nlp(text)
  words=[]
  for token in doc:
    if token.is_stop:
      continue
    words.append(token.lemma_)

  return ''.join(words)

# %%
data1['Preprocssed_text']=data1['Cleaned_text'].apply(preprocess)

# %%
data1
# Out:
#         sentiment                                            content  \
# 0           empty  @tiffanylue i know  i was listenin to bad habi...
# 1         sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2         sadness                Funeral ceremony...gloomy friday...
# 3      enthusiasm               wants to hang out with friends SOON!
# 4         neutral  @dannycastillo We want to trade with someone w...
# ...           ...                                                ...
# 39995     neutral                                   @JohnLloydTaylor
# 39996        love                     Happy Mothers Day  All my love
# 39997        love  Happy Mother's Day to all the mommies out ther...
# 39998   happiness  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999        love  @mopedronin bullet train from tokyo    the gf ...
#
#                                             Cleaned_text  emotion  \
# 0      iffanylu know listenin bad habit earlier start...        2
# 1                 layin n bed headach ughhhh waitin call       10
# 2                           funer ceremoni gloomi friday       10
# 3                                  want hang friend soon        3
# 4      annycastillo want trade someon houston ticket one        8
# ...                                                  ...      ...
# 39995                                     ohnlloydtaylor        8
# 39996                              happi mother day love        7
# 39997  happi mother day mommi woman man long momma so...        7
# 39998  iariley wassup beauti follow peep new hit sing...        5
# 39999  opedronin bullet train tokyo gf visit japan si...        7
#
#                                         Preprocssed_text  Label
# 0          iffanyluknowlisteninbadhabitearlystartfreakin      2
# 1                           layinnbedheadachughhhhwaitin     10
# 2                              funerceremonigloomifriday     10
# 3                                     wanthangfriendsoon      3
# 4               annycastillowanttradesomeonhoustonticket      8
# ...                                                  ...    ...
# 39995                                     ohnlloydtaylor      8
# 39996                                 happimotherdaylove      7
# 39997      happimotherdaymommiwomanmanlongmommasomeonday      7
# 39998  iarileywassupbeautifollowpeepnewhitsinglwwwmys...      5
# 39999  opedroninbullettraintokyogfvisitjapansincthurs...      7
#
# [40000 rows x 6 columns]

# %%
data1["Label"]=data1['emotion']

# %%
x_train, x_test, y_train, y_test = train_test_split(data1['Preprocssed_text'], data1['Label'],
                                                    test_size=0.2, random_state=42, stratify=data1['Label'])

# %%
clf = Pipeline([
    ('vectorizer_tri_grams', TfidfVectorizer()),
    ('naive_bayes', (MultinomialNB()))
])

# %%
clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer_tri_grams', TfidfVectorizer()),
#                 ('naive_bayes', MultinomialNB())])

# %%
y_pred = clf.predict(x_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.21925
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.00      0.00      0.00        36
#            2       0.00      0.00      0.00       165
#            3       0.00      0.00      0.00       152
#            4       0.00      0.00      0.00       355
#            5       0.40      0.01      0.01      1042
#            6       0.00      0.00      0.00       265
#            7       0.70      0.02      0.05       768
#            8       0.22      0.99      0.36      1728
#            9       0.00      0.00      0.00       305
#           10       0.40      0.01      0.02      1033
#           11       0.00      0.00      0.00       437
#           12       0.25      0.01      0.01      1692
#
#     accuracy                           0.22      8000
#    macro avg       0.15      0.08      0.03      8000
# weighted avg       0.27      0.22      0.09      8000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
